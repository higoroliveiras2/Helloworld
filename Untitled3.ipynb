# %% [markdown]
# <a href="https://colab.research.google.com/github/higoroliveiras2/Helloworld/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Este exemplo mostra como se conectar ao Banco de Dados e executar uma consulta simples.

## Instalar o conector MySQL
# !pip install mysql-connector-python

## Importar biblioteca
import mysql.connector

## Conectar ao banco de dados
conexao = mysql.connector.connect(
    host="banco2512a.mysql.dbaas.com.br",
    user="banco2512a",
    password="Senai@2512",
    database="banco2512a"
)
print("✅ Conexão estabelecida com sucesso!\n")

## Criar cursor
cursor = conexao.cursor()

# Exemplo de SELECT básico
cursor.execute("SELECT nome, email FROM clientes;")

# Capturar e exibir resultados
print("📋 Clientes cadastrados:\n")
for (nome, email) in cursor.fetchall():
    print(f"Nome: {nome:<25} | Email: {email}")

## Encerrar cursor e conexão
cursor.close()
conexao.close()
print("\n🔒 Conexão encerrada com sucesso!")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 38.8 MB/s eta 0:00:00
# ...
# ✅ Conexão estabelecida com sucesso!
#
# 📋 Clientes cadastrados:
#
# Nome: João Silva                | Email: email@email.com
# Nome: Maria Oliveira            | Email: maria.oliveira@email.com
# Nome: Pedro Souza               | Email: pedro.souza@email.com
# Nome: Ana Costa                 | Email: ana.costa@email.com
# Nome: Lucas Almeida             | Email: lucas.almeida@email.com
# Nome: Carla Rodrigues           | Email: carla.rodrigues@email.com
# Nome: Fernando Pereira          | Email: fernando.pereira@email.com
# Nome: Juliana Martins           | Email: juliana.martins@email.com
# Nome: Ricardo Lima              | Email: ricardo.lima@email.com
# Nome: Patrícia Mendes           | Email: patricia.mendes@email.com
# Nome: Fábio Cardoso             | Email: fabio.cardoso@email.com
# Nome: Camila Gomes              | Email: camila.gomes@email.com
# ...
